# %%
import pandas as pd

# %%
As= pd.read_csv('../data/Labour Statistics - Sheet3.csv',skiprows=0)

# %%
As
# Out:
#     Occupation code  \
# 0           00-0000
# 1            Nov-00
# 2           11-1011
# 3           11-1021
# 4           11-1031
# ..              ...
# 722         53-7065
# 723         53-7071
# 724         53-7072
# 725         53-7081
# 726         53-7199
#
#     Occupation title (click on the occupation title to view its profile)  \
# 0                                      All Occupations
# 1                               Management Occupations
# 2                                     Chief Executives
# 3                      General and Operations Managers
# 4                                          Legislators
# ..                                                 ...
# 722                         Stockers and Order Fillers
# 723   Gas Compressor and Gas Pumping Station Operators
# 724            Pump Operators, Except Wellhead Pumpers
# 725          Refuse and Recyclable Material Collectors
# 726                 Material Moving Workers, All Other
#
# ...

# %%
df = pd.DataFrame(As)

# %%
Order_df = df.sort_values('Annual mean wage', ascending=False)

# %%
df
# Out:
#     Occupation code  \
# 0           00-0000
# 1            Nov-00
# 2           11-1011
# 3           11-1021
# 4           11-1031
# ..              ...
# 722         53-7065
# 723         53-7071
# 724         53-7072
# 725         53-7081
# 726         53-7199
#
#     Occupation title (click on the occupation title to view its profile)  \
# 0                                      All Occupations
# 1                               Management Occupations
# 2                                     Chief Executives
# 3                      General and Operations Managers
# 4                                          Legislators
# ..                                                 ...
# 722                         Stockers and Order Fillers
# 723   Gas Compressor and Gas Pumping Station Operators
# 724            Pump Operators, Except Wellhead Pumpers
# 725          Refuse and Recyclable Material Collectors
# 726                 Material Moving Workers, All Other
#
# ...

# %%
df['Annual mean wage'].dropna(inplace = True)

# %%
df
# Out:
#     Occupation code  \
# 0           00-0000
# 1            Nov-00
# 2           11-1011
# 3           11-1021
# 4           11-1031
# ..              ...
# 722         53-7065
# 723         53-7071
# 724         53-7072
# 725         53-7081
# 726         53-7199
#
#     Occupation title (click on the occupation title to view its profile)  \
# 0                                      All Occupations
# 1                               Management Occupations
# 2                                     Chief Executives
# 3                      General and Operations Managers
# 4                                          Legislators
# ..                                                 ...
# 722                         Stockers and Order Fillers
# 723   Gas Compressor and Gas Pumping Station Operators
# 724            Pump Operators, Except Wellhead Pumpers
# 725          Refuse and Recyclable Material Collectors
# 726                 Material Moving Workers, All Other
#
# ...

# %%
Order_df = df.sort_values('Annual mean wage', ascending=True)

# %%
Order_df
# Out:
#     Occupation code  \
# 409         39-5093
# 711         53-6031
# 408         39-5092
# 368         35-2011
# 375         35-3023
# ..              ...
# 298         29-1218
# 296         29-1211
# 275         29-1022
# 302         29-1248
# 2           11-1011
#
#     Occupation title (click on the occupation title to view its profile)  \
# 409                                         Shampooers
# 711       Automotive and Watercraft Service Attendants
# 408                        Manicurists and Pedicurists
# 368                                   Cooks, Fast Food
# 375                      Fast Food and Counter Workers
# ..                                                 ...
# 298                    Obstetricians and Gynecologists
# 296                                  Anesthesiologists
# 275                    Oral and Maxillofacial Surgeons
# 302                  Surgeons, Except Ophthalmologists
# 2                                     Chief Executives
#
# ...

# %%
df = df[["Occupation title (click on the occupation title to view its profile)", "Location quotient", "Annual mean wage"]]

# %%
print(df)
# Out:
#     Occupation title (click on the occupation title to view its profile)  \
# 0                                      All Occupations
# 1                               Management Occupations
# 2                                     Chief Executives
# 3                      General and Operations Managers
# 4                                          Legislators
# ..                                                 ...
# 722                         Stockers and Order Fillers
# 723   Gas Compressor and Gas Pumping Station Operators
# 724            Pump Operators, Except Wellhead Pumpers
# 725          Refuse and Recyclable Material Collectors
# 726                 Material Moving Workers, All Other
#
#      Location quotient  Annual mean wage
# 0                 1.00             66790
# 1                 1.04            165830
# 2                 0.48            252880
# 3                 1.03            167160
# 4                 0.85             58600
# ...

# %%
df
# Out:
#     Occupation title (click on the occupation title to view its profile)  \
# 0                                      All Occupations
# 1                               Management Occupations
# 2                                     Chief Executives
# 3                      General and Operations Managers
# 4                                          Legislators
# ..                                                 ...
# 722                         Stockers and Order Fillers
# 723   Gas Compressor and Gas Pumping Station Operators
# 724            Pump Operators, Except Wellhead Pumpers
# 725          Refuse and Recyclable Material Collectors
# 726                 Material Moving Workers, All Other
#
#      Location quotient  Annual mean wage
# 0                 1.00             66790
# 1                 1.04            165830
# 2                 0.48            252880
# 3                 1.03            167160
# 4                 0.85             58600
# ...

# %%
df.to_csv('../data/BLS_Chart.csv', index=False)
